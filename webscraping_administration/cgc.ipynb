# %%
from bs4 import BeautifulSoup
import requests

url = "https://iiitdwd.ac.in/placements/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    #print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link as="image" href="/_next/static/media/campus_0.ceaad1dc.webp" rel="preload"/>
#   <link as="image" href="/_next/static/media/director.7163fe52.jpg" rel="preload"/>
#   <link data-precedence="next" href="/_next/static/chunks/e1e1e2ddd69dbac2.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="/_next/static/chunks/5e3e3acbf06367a1.js" rel="preload"/>
#   <script async="" src="/_next/static/chunks/ba46a41815f396e0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/5633788a972e5355.js">
#   </script>
#   <script async="" src="/_next/static/chunks/2e7ec28d76cf6fc5.js">
#   </script>
#   <script async="" src="/_next/static/chunks/b91c490b847e60d5.js">
#   </script>
#   <script async="" src="/_next/static/chunks/0cc2b12efcca02d8.js">
#   </script>
# ...

# %%
basic = soup.find('div', class_="mb-16")
print(basic.h1.text)
# Out:
# WHY RECRUIT FROM US?
