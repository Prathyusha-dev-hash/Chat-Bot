# %%
# Opening a csv file
import csv
file1 = open("administration.csv", "w+")
# Creating a csv writer object
csv_writer = csv.writer(file1)  
# Writing the header
csv_writer.writerow(["admin_id", "role_name", "person_name", "designation", "email", "phone","office_location","responsibilites", "image_url"])
file1.close()

# %%
# Visitor 
from bs4 import BeautifulSoup
import requests
file1 = open("administration.csv", "a")
# Creating a csv writer object
csv_writer = csv.writer(file1)
url = "https://iiitdwd.ac.in/visitor/"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    #print(soup.prettify())
    title = soup.find("div", class_="text-center mb-8")
    role_name = title.h1.text
    admin_id = "AttributeError"
    person_name= soup.find("div", class_="mb-6").h2.text
    designation = soup.find("div", class_="mb-6").p.text
    admin_id = person_name.split(" ")[-1]
    email = "AttributeError"
    phone = "AttributeError"
    office_location = soup.find("div", class_ = "flex items-center gap-3").span.text
    responsibilities = soup.find("p", class_="text-title-3 text-gray-600 mt-4 italic").text
    image_url = soup.find("div", class_="absolute inset-0 rounded-full border-4 border-white shadow-lg overflow-hidden").img['src']
    print(admin_id)
    print(role_name)
    print(person_name)
    print(designation)
    print(email)
    print(phone)
    print(office_location)
    print(responsibilities)
    print(image_url)
    # Writing the data to the csv file
    csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
    file1.close()
# Out:
# Murmu
# Distinguished Visitor
# Smt. Droupadi Murmu
# The Hon'ble President of India
# AttributeError
# AttributeError
# Rashtrapati Bhavan, New Delhi, India
# We are honored to announce that the Hon'ble President of India, Smt. Droupadi Murmu is the Visitor of our Institute.
# https://iiitdwd.ac.in/images/droupadi_murmu.jpeg

# %%
# Chairperson
url = "https://iiitdwd.ac.in/chairperson/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    role_name = soup.find("div", class_ = "absolute left-0 right-0 bottom-16 w-[87.5vw] max-w-[1680px] mx-auto z-10").h1.text
    image_url = soup.find("div",class_ = "border border-primary w-full max-w-[400px]").img['src']
    
    email = soup.find("div",class_ = "flex items-center space-x-2").a.text
    person_name = soup.find("div", class_ = "flex-1 space-y-6").h1.text
    admin_id = person_name.split(" ")[-1]
    designation = soup.find("div", class_ = "flex-1 space-y-6").p.text
    phone = "AttributeError"
    office_location = "AttributeError"
    responsibilities = ""
    for row in (soup.find_all("p", class_="text-gray-700 text-title-3 font-normal mb-4")):
        responsibilities += row.text + " "
    

    print(admin_id)
    print(role_name)
    print(person_name)
    print(designation)
    print(email)
    print(phone)
    print(office_location)
    print(responsibilities)
    print(image_url)
    # Writing the data to the csv file
    csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
    file1.close()
# Out:
# Vembu
# Chairperson
# Dr. Sridhar Vembu
# Chairperson, IIIT Dharwad
# chairperson@iiitdwd.ac.in
# AttributeError
# AttributeError
# Dr. Sridhar Vembu is the co-founder and Chief Scientist of Zoho Corporation, a globally respected technology leader and a pioneer in rural development through innovation. Raised in a humble village in Tamil Nadu, India, Dr. Vembu's academic journey led him to earn a degree in Electrical Engineering from IIT Madras and a Ph.D. from Princeton University.
# ...

# %%
# Board of governers
# Chairperson
url = "https://iiitdwd.ac.in/governing-bodies/board/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    role_name = soup.find("div", class_ = "py-8").h1.text
    image_url = soup.find("div", class_="w-full aspect-square overflow-hidden").img['src']
    
    email = "AttributeError"
    person_name = soup.find("div", class_="py-8").h3.text
    admin_id = person_name.split(" ")[-1]
    designation = soup.find("div", class_="py-8").p.text
    phone = "AttributeError"
    office_location = "AttributeError"
    responsibilities = "AttributeError"
    
    print(admin_id)
    print(role_name)
    print(person_name)
    print(designation)
    print(email)
    print(phone)
    print(office_location)
    print(responsibilities)
    print(image_url)
    
    # Writing the data to the csv file
    csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
    file1.close()
# Out:
# Vembu
# Chairperson
# Dr. Sridhar Vembu
# Chairperson, IIIT Dharwad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/Sridhar Vembu.webp

# %%
# Board  of governers
# Members
url = "https://iiitdwd.ac.in/governing-bodies/board/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    
    members = soup.find_all("div", class_="py-8")
    count = 0 
    for member in members:
        count +=1

        if count == 2:
            persons = member.find("div", class_="grid grid-cols-1 sm:grid-cols-2 md:grid-cols-3 lg:grid-cols-4 gap-6")
            real_persons = persons.find_all("div", class_ = "flex flex-col items-center relative border border-border/50 text-center rounded-xl shadow-lg hover:shadow-xl hover:scale-[1.02] bg-white transition-[shadow,scale] duration-300 overflow-clip")
           
            for person in real_persons:
                role_name = member.h1.text
                image_url = person.find("div", class_="w-full aspect-square overflow-hidden").img['src']
                email = "AttributeError"
                person_name = person.h3.text
                admin_id = person_name.split(" ")[-1]
                designation = person.p.text
                phone = "AttributeError"
                office_location = "AttributeError"
                responsibilities = "AttributeError"

                
                print(admin_id)
                print(role_name)
                print(person_name)
                print(designation)
                print(email)
                print(phone)
                print(office_location)
                print(responsibilities)
                print(image_url)
            
        
        # Writing the data to the csv file
                csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
file1.close()
# Out:
# Gupta
# Members
# Smt. Saumya Gupta
# Joint Secretary (TE), Ministry of Education, Government of India
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/saumya_gupta.jpg
# I.A.S
# Members
# Dr. Ekroop Caur, I.A.S
# Secretary to Government Department of Electronics Information Technology Biotechnology and Science & Technology. Government of Karnataka
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/ekroop_caur.jpg
# IAS
# Members
# Shri Pavan Kumar Malapati, IAS
# Department of Science & Technology & Managing Director, KSTePS Government of Karnataka
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/pavan_kumar_malapati.jpg
# Desai
# Members
# Prof. Uday B. Desai
# Former Director, IIT Hyderabad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/uday_b_desai.jpg
# Sadagopan
# Members
# ...

# %%
# Board  of governers
# Members
url = "https://iiitdwd.ac.in/governing-bodies/board/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    
    members = soup.find_all("div", class_="py-8")
    count = 0 
    for member in members:
        count +=1
        
        if count == 3:
                role_name = member.h1.text
                image_url = member.find("div", class_="w-full aspect-square overflow-hidden").img['src']
                email = "AttributeError"
                person_name = member.h3.text
                admin_id = person_name.split(" ")[-1]
                designation = member.p.text
                phone = "AttributeError"
                office_location = "AttributeError"
                responsibilities = "AttributeError"

                
                print(admin_id)
                print(role_name)
                print(person_name)
                print(designation)
                print(email)
                print(phone)
                print(office_location)
                print(responsibilities)
                print(image_url)
            
        
        # Writing the data to the csv file
                csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
file1.close()
# Out:
# Vitlapur
# Non Member Secretary
# Mr. Ravi B. Vitlapur
# Officiating Registrar, IIIT Dharwad, Non Member Secretary, IIIT Dharwad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/ravi_b_vitlapur.jpg

# %%
# Director
url = "https://iiitdwd.ac.in/director/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    members = soup.find_all("div", class_="py-8")
    count = 0
    for member in members:
        count += 1
    role_name = soup.find("div", class_="absolute left-0 right-0 bottom-16 w-[87.5vw] max-w-[1680px] mx-auto z-10").h1.text
    image_url = soup.find("div", class_="border border-primary w-full max-w-[400px]").img['src']
    
    email = soup.find("div", class_="flex items-center space-x-2").a.text
    person_name = soup.find("div", class_="flex-1 space-y-6").h1.text
    admin_id = person_name.split(" ")[-1]
    designation = soup.find("div", class_="flex-1 space-y-6").p.text
    phone = "AttributeError"
    office_location = "IIIT Dharwad, Karnataka, India"
    responsibilities = ""
    for row in (soup.find_all("p", class_="text-gray-700 text-title-3 font-normal mb-4")):
        responsibilities += row.text + " "
    

    print(admin_id)
    print(role_name)
    print(person_name)
    print(designation)
    print(email)
    print(phone)
    print(office_location)
    print(responsibilities)
    print(image_url)
    
    # Writing the data to the csv file
    csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
file1.close()
# Out:
# Prasanna
# Director
# Prof. S. R. Mahadeva Prasanna
# Director, IIIT Dharwad
# director@iiitdwd.ac.in
# AttributeError
# IIIT Dharwad, Karnataka, India
# ...

# %%
# The Senate
url = "https://iiitdwd.ac.in/governing-bodies/senate/"
response = requests.get(url)
if response.status_code == 200:
    count = 0 
    
    soup = BeautifulSoup(response.content, 'html.parser')
    members = soup.find_all("div", class_="py-8")
    for member in members:
        count += 1
        
        if count == 1:
            role_name = member.h1.text
            image_url = member.find("div", class_="w-full aspect-square overflow-hidden").img['src']
            email = "AttributeError"
            person_name = member.h3.text
            admin_id = person_name.split(" ")[-1]
            designation = member.p.text
            phone = "AttributeError"
            office_location = "AttributeError"
            responsibilities = "AttributeError"

            
            print(admin_id)
            print(role_name)
            print(person_name)
            print(designation)
            print(email)
            print(phone)
            print(office_location)
            print(responsibilities)
            print(image_url)
        
        # Writing the data to the csv file
            csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])

        if count == 2:
            persons = member.find("div", class_="grid grid-cols-1 sm:grid-cols-2 md:grid-cols-3 lg:grid-cols-4 gap-6")
            real_persons = persons.find_all("div", class_="flex flex-col items-center relative border border-border/50 text-center rounded-xl shadow-lg hover:shadow-xl hover:scale-[1.02] bg-white transition-[shadow,scale] duration-300 overflow-clip")
            for person in real_persons:
                role_name = member.h1.text
                image_url = person.find("div", class_="w-full aspect-square overflow-hidden").img['src']
                email = "AttributeError"
                person_name = person.h3.text
                admin_id = person_name.split(" ")[-1]
                designation = person.p.text
                phone = "AttributeError"
                office_location = "AttributeError"
                responsibilities = "AttributeError"

                
                print(admin_id)
                print(role_name)
                print(person_name)
                print(designation)
                print(email)
                print(phone)
                print(office_location)
                print(responsibilities)
                print(image_url)

    
                # Writing the data to the csv file
                csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
file1.close()
# Out:
# Prasanna
# Chairman Senate
# Prof. S. R. Mahadeva Prasanna
# Director, Chairman, IIIT Dharwad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/s_r_mahadeva_prasanna.jpg
# Mutyam
# Members
# Prof. Madhu Mutyam
# Professor, IIT Madras
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/madhu_mutyam.png
# Ramamurthy
# Members
# Prof. Badrinath Ramamurthy
# Professor, IIIT Bangalore
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/badrinath_ramamurthy.jpg
# Subrahmanyam
# Members
# Prof. Ch. Subrahmanyam
# Professor, IIT Hyderabad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/ch_subrahmanyam.jpeg
# Patil
# Members
# Prof. Dhiraj V. Patil
# Associate Professor, IIT Dharwad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/dhiraj_v_patil.png
# ...

# %%
# Finance Committee
url = "https://iiitdwd.ac.in/governing-bodies/financial/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    count = 0
    members = soup.find_all("div", class_="py-8")
    for member in members:
        count += 1
        
        if count == 1:
            role_name = member.h1.text
            image_url = member.find("div", class_="w-full aspect-square overflow-hidden").img['src']
            email = "AttributeError"
            person_name = member.h3.text
            admin_id = person_name.split(" ")[-1]
            designation = member.p.text
            phone = "AttributeError"
            office_location = "AttributeError"
            responsibilities = "AttributeError"

            
            print(admin_id)
            print(role_name)
            print(person_name)
            print(designation)
            print(email)
            print(phone)
            print(office_location)
            print(responsibilities)
            print(image_url)

        # Writing the data to the csv file
            csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])

        if count == 2:
            persons = member.find("div", class_="grid grid-cols-1 sm:grid-cols-2 md:grid-cols-3 lg:grid-cols-4 gap-6")
            real_persons = persons.find_all("div", class_="flex flex-col items-center relative border border-border/50 text-center rounded-xl shadow-lg hover:shadow-xl hover:scale-[1.02] bg-white transition-[shadow,scale] duration-300 overflow-clip")
            for person in real_persons:
                role_name = member.h1.text
                image_url = person.find("div", class_="w-full aspect-square overflow-hidden").img['src']
                email = "AttributeError"
                person_name = person.h3.text
                admin_id = person_name.split(" ")[-1]
                designation = person.p.text
                phone = "AttributeError"
                office_location = "AttributeError"
                responsibilities = "AttributeError"

                
                print(admin_id)
                print(role_name)
                print(person_name)
                print(designation)
                print(email)
                print(phone)
                print(office_location)
                print(responsibilities)
                print(image_url)

    
                # Writing the data to the csv file
                csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
    role_name = soup.find("div", class_="py-8").h1

# %%
from bs4 import BeautifulSoup
import requests
import csv
file1 = open("administration.csv", "a")
# Creating a csv writer object
csv_writer = csv.writer(file1)

# %%
# Building And Works Committee
url = "https://iiitdwd.ac.in/governing-bodies/building/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    #print(soup.prettify())
    members = soup.find("div", class_="py-8")
    persons = members.find_all("div", class_="flex flex-col items-center relative border border-border/50 text-center rounded-xl shadow-lg hover:shadow-xl hover:scale-[1.02] bg-white transition-[shadow,scale] duration-300 overflow-clip")
    for person in persons :
        role_name = soup.find("h1", class_ = "uppercase font-semibold z-[1] before:-z-[1] -top-[2px] w-fit rounded-full text-white bg-main before:w-[calc(100%+10px)] px-6 py-2 relative mb-6").text
        image_url = person.find("div", class_="w-full aspect-square overflow-hidden").img['src']
        email = "AttributeError"
        person_name = person.h3.text
        admin_id = person_name.split(" ")[-1]
        designation = person.p.text
        phone = "AttributeError"
        office_location = "AttributeError"
        responsibilities = "AttributeError"
    

    
        print(admin_id)
        print(role_name)
        print(person_name)
        print(designation)
        print(email)
        print(phone)
        print(office_location)
        print(responsibilities)
        print(image_url)

        # Writing the data to the csv file
        csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])

file1.close()
# Out:
# Khincha
# Building & Works Committee
# Prof. H P Khincha
# Chairman
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/h_p_khincha.jpg
# Murthy
# Building & Works Committee
# Prof. B R Srinivasa Murthy
# Member
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/b_r_srinivasa_murthy.jpg
# N.
# Building & Works Committee
# Prof. Anuradha N.
# Member
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/anuradha_n.jpg
# Prasanna
# Building & Works Committee
# Prof. S. R. Mahadeva Prasanna
# Director, IIIT-Dharwad
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# https://iiitdwd.ac.in/images/s_r_mahadeva_prasanna.jpg
# Vitlapur
# Building & Works Committee
# Mr. Ravi B Vitlapur
# Member
# AttributeError
# AttributeError
# AttributeError
# AttributeError
# /placeholder-person.png
# J
# Building & Works Committee
# ...

# %%
# Deans / PIC
url = "https://iiitdwd.ac.in/deans/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    
    members = soup.find_all("div", class_="grid grid-cols-1 md:grid-cols-2 lg:grid-cols-3 xl:grid-cols-4 gap-6 ")
    for member in members:
        role_name = member.p.text
        image_url = member.find("div", class_="h-full w-full").img['src']
        email = member.svg.text
        person_name = member.h2.text
        admin_id = person_name.split(" ")[-1]
        designation = role_name + "," + soup.find("p", class_="text-body text-gray-500").text
        phone = "AttributeError"
        office_location = "AttributeError"
        responsibilities = "AttributeError"

        
        print(admin_id)
        print(role_name)
        print(person_name)
        print(designation)
        print(email)
        print(phone)
        print(office_location)
        print(responsibilities)
        print(image_url)

        # Writing the data to the csv file
        #csv_writer.writerow([admin_id, role_name, person_name, designation, email, phone, office_location, responsibilities, image_url])
